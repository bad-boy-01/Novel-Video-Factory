# %% [markdown]
# # Novel Video Factory - Kaggle Deployment
# This notebook will install all necessary local models (Ollama, Diffusers, TTS) and run the full AI Video Factory.

# %%
# !bash kaggle_setup.sh

# %%
# Wait a moment to ensure Ollama is fully responsive
import time
time.sleep(5)

# Run the pipeline!
# !python main.py dummy_novel --stage all
